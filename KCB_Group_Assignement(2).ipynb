# %% [markdown]
# ## Introduction
# ### KCB Group assignment
# #### Group Members
#
# 1. Esther Ndunge Muinde
# 2. Wayne Otieno
# 3. Faith Jeptoo
# 4. Doreen Tenai
# 5. Ali Mtulu Funda
#
# This dataset contains the Jobs and Salaries in Datascience
# The aim of this assignment is to evaluate our understanding on the concepts taught so far.

# %% [markdown]
# Upload and Mount Google Drive content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Load the dataset to Colab and list the first ten and last ten records on the dataset.

# %%
df_jobs = pd.read_csv('/content/drive/My Drive/jobs_in_data.csv')

# %%
# Last 10 jobs
df_jobs.tail(10)
# Out:
#       work_year                           job_title  \
# 9345       2020           Machine Learning Engineer
# 9346       2021            Director of Data Science
# 9347       2021                      Data Scientist
# 9348       2021  Applied Machine Learning Scientist
# 9349       2021                       Data Engineer
# 9350       2021                     Data Specialist
# 9351       2020                      Data Scientist
# 9352       2021            Principal Data Scientist
# 9353       2020                      Data Scientist
# 9354       2020               Business Data Analyst
#
#                       job_category salary_currency  salary  salary_in_usd  \
# 9345       Machine Learning and AI             EUR   40000          45618
# 9346     Data Science and Research             USD  168000         168000
# 9347     Data Science and Research             SGD  160000         119059
# 9348       Machine Learning and AI             USD  423000         423000
# 9349              Data Engineering             EUR   24000          28369
# 9350  Data Management and Strategy             USD  165000         165000
# 9351     Data Science and Research             USD  412000         412000
# 9352     Data Science and Research             USD  151000         151000
# 9353     Data Science and Research             USD  105000         105000
# 9354                 Data Analysis             USD  100000         100000
#
#      employee_residence experience_level employment_type work_setting  \
# 9345            Croatia           Senior       Full-time       Remote
# 9346              Japan           Senior       Full-time    In-person
# 9347          Singapore        Mid-level       Full-time       Remote
# 9348      United States        Mid-level       Full-time       Hybrid
# 9349              Malta        Mid-level       Full-time       Hybrid
# 9350      United States           Senior       Full-time       Remote
# 9351      United States           Senior       Full-time       Remote
# 9352      United States        Mid-level       Full-time       Remote
# 9353      United States      Entry-level       Full-time       Remote
# 9354      United States      Entry-level        Contract       Remote
#
#      company_location company_size
# 9345          Croatia            S
# 9346            Japan            S
# 9347           Israel            M
# 9348    United States            L
# 9349            Malta            L
# 9350    United States            L
# 9351    United States            L
# 9352    United States            L
# 9353    United States            S
# 9354    United States            L

# %%
# First 10 jobs
df_jobs.head(10)
# Out:
#    work_year                    job_title                    job_category  \
# 0       2023         Data DevOps Engineer                Data Engineering
# 1       2023               Data Architect  Data Architecture and Modeling
# 2       2023               Data Architect  Data Architecture and Modeling
# 3       2023               Data Scientist       Data Science and Research
# 4       2023               Data Scientist       Data Science and Research
# 5       2023               Data Scientist       Data Science and Research
# 6       2023               Data Scientist       Data Science and Research
# 7       2023  Machine Learning Researcher         Machine Learning and AI
# 8       2023  Machine Learning Researcher         Machine Learning and AI
# 9       2023                Data Engineer                Data Engineering
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
# 5             USD  130000         130000      United States           Senior
# 6             USD  100000         100000      United States           Senior
# 7             USD  224400         224400      United States        Mid-level
# 8             USD  138700         138700      United States        Mid-level
# 9             USD  210000         210000      United States        Executive
#
#   employment_type work_setting company_location company_size
# 0       Full-time       Hybrid          Germany            L
# 1       Full-time    In-person    United States            M
# 2       Full-time    In-person    United States            M
# 3       Full-time    In-person    United States            M
# 4       Full-time    In-person    United States            M
# 5       Full-time       Remote    United States            M
# 6       Full-time       Remote    United States            M
# 7       Full-time    In-person    United States            M
# 8       Full-time    In-person    United States            M
# 9       Full-time       Remote    United States            M

# %% [markdown]
# 2. Check the total number of entries in the database, and then identify if there are any missing values in the dataset. If so, drop the records containing missing values

# %%
# Check the total number of entries
total_entries = len(df_jobs)
print(f"Total entries: {total_entries}")

# Check for missing values in the dataset
missing_values = df_jobs.isnull().sum()
print(f"Missing values:\n{missing_values}")

# Drop records containing missing values
df_jobs.dropna(inplace=True)

# Verify that there are no more missing values
missing_values = df_jobs.isnull().sum()
print(f"Missing values after dropping:\n{missing_values}")
# Out:
# Total entries: 9355
# Missing values:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64
# Missing values after dropping:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %% [markdown]
# #### Dataset Overview
#
# The Dataset consists of 9355 entries and 12 columns
# It includes information on various aspects related to job positions and employment
# There are no missing values in any of the columns

# %%
df_jobs.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# mean   2022.760449  149927.981293  150299.495564
# std       0.519470   63608.835387   63177.372024
# min    2020.000000   14000.000000   15000.000000
# 25%    2023.000000  105200.000000  105700.000000
# 50%    2023.000000  143860.000000  143000.000000
# 75%    2023.000000  187000.000000  186723.000000
# max    2023.000000  450000.000000  450000.000000

# %% [markdown]
# #### Summary
#
# * The dataset predominantly consists of data from the year 2023 with a few entries from 2020. There is little variability in the distribution of work years
#
# * The average salary across all jobs is approximately 149, 928 with a standard deviation of 63,609 indicating significant variability in salaries
# Overall there is notable variability in the salary amounts

# %% [markdown]
# 4. Create a pie chart showing the most common job titles in the dataset. Create a new
# dataframe by filtering the current one using the “Data Scientist” Job title. Save and
# export this dataframe as CSV. We will be working with this dataframe going forward

# %%
# Get the top 5 most common job titles
top_5_job_titles = df_jobs['job_title'].value_counts().head(5)

# Create a pie chart
plt.figure(figsize=(10, 7))
plt.pie(top_5_job_titles, labels=top_5_job_titles.index, autopct='%1.1f%%')
plt.title('Most Common Job Titles')
plt.show()

# %% [markdown]
# Create a new
# dataframe by filtering the current one using the “Data Scientist” Job title. Save and
# export this dataframe as CSV. We will be working with this dataframe going forward.

# %%
#Filter the dataframe to contain Data scientist job title
# Save it to csv

df_ds = df_jobs[df_jobs['job_title'] == 'Data Scientist']
df_ds.to_csv('data_scientist_jobs.csv', index=False)

# %%
df_ds.head()
# Out:
#     work_year       job_title               job_category salary_currency  \
# 3        2023  Data Scientist  Data Science and Research             USD
# 4        2023  Data Scientist  Data Science and Research             USD
# 5        2023  Data Scientist  Data Science and Research             USD
# 6        2023  Data Scientist  Data Science and Research             USD
# 13       2023  Data Scientist  Data Science and Research             GBP
#
#     salary  salary_in_usd employee_residence experience_level employment_type  \
# 3   212000         212000      United States           Senior       Full-time
# 4    93300          93300      United States           Senior       Full-time
# 5   130000         130000      United States           Senior       Full-time
# 6   100000         100000      United States           Senior       Full-time
# 13   35000          43064     United Kingdom        Mid-level       Full-time
#
#    work_setting company_location company_size
# 3     In-person    United States            M
# 4     In-person    United States            M
# 5        Remote    United States            M
# 6        Remote    United States            M
# 13    In-person   United Kingdom            M

# %% [markdown]
# 5. Analyse salary by experience level. Calculate the total, min, max and average salaries
# for each experience level (Entry-level, Mid-level, Senior, etc.) and visualise the
# differences

# %%
salary_exp = df_ds.groupby('experience_level')['salary_in_usd'].agg(['sum', 'min', 'max', 'mean'])
salary_exp
# Out:
#                         sum    min     max           mean
# experience_level
# Entry-level         8133352  16000  190000   88406.000000
# Executive           5656892  78000  300000  188563.066667
# Mid-level          38024174  25000  260600  116281.877676
# Senior            259824121  20171  412000  168716.961688
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# salary_exp['sum'].plot(kind='hist', bins=20, title='sum')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# salary_exp['min'].plot(kind='hist', bins=20, title='min')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# salary_exp['max'].plot(kind='hist', bins=20, title='max')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# salary_exp['mean'].plot(kind='hist', bins=20, title='mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# salary_exp.plot(kind='scatter', x='sum', y='min', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# salary_exp.plot(kind='scatter', x='min', y='max', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# salary_exp.plot(kind='scatter', x='max', y='mean', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# salary_exp['sum'].plot(kind='line', figsize=(8, 4), title='sum')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# salary_exp['min'].plot(kind='line', figsize=(8, 4), title='min')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# salary_exp['max'].plot(kind='line', figsize=(8, 4), title='max')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# salary_exp['mean'].plot(kind='line', figsize=(8, 4), title='mean')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['sum'].plot(kind='hist', bins=20, title='sum')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['min'].plot(kind='hist', bins=20, title='min')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['max'].plot(kind='hist', bins=20, title='max')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['mean'].plot(kind='hist', bins=20, title='mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('experience_level').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='sum', y='min', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='min', y='max', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='max', y='mean', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['sum'].plot(kind='line', figsize=(8, 4), title='sum')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['min'].plot(kind='line', figsize=(8, 4), title='min')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['max'].plot(kind='line', figsize=(8, 4), title='max')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['mean'].plot(kind='line', figsize=(8, 4), title='mean')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_12['experience_level'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_12, x='sum', y='experience_level', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['experience_level'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='min', y='experience_level', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['experience_level'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='max', y='experience_level', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['experience_level'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='mean', y='experience_level', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
salary_exp_df = pd.DataFrame(salary_exp)
salary_exp_df
# Out:
#                         sum    min     max           mean
# experience_level
# Entry-level         8133352  16000  190000   88406.000000
# Executive           5656892  78000  300000  188563.066667
# Mid-level          38024174  25000  260600  116281.877676
# Senior            259824121  20171  412000  168716.961688

# %%
# Visualize the salary differences
salary_exp_df[['min', 'max', 'mean']].plot(kind='bar', figsize=(10,6))
plt.title('Salary by Experience Level')
plt.xlabel('Experience Level')
plt.ylabel('Salary (USD)')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend(['Minimum', 'Maximum', 'Mean'])
plt.show()

# %% [markdown]
# 6. Only focusing on the United Kingdom, Compare salaries for full-time, part-time, and
# contract employees and identify any trends

# %%
df_ds.shape
# Out:
# (1989, 12)

# %%
# Filter the DataFrame for employees residing in the United Kingdom
uk_df = df_ds[df_ds['employee_residence'] == 'United Kingdom']

# Group the filtered DataFrame by employment_type and calculate summary statistics for salary
salary_by_employment_type = uk_df.groupby('employment_type')['salary_in_usd'].describe()

# Visualize the salary differences
salary_by_employment_type[['mean', '25%', '50%', '75%']].plot(kind='bar', figsize=(10,6))
plt.title('Salary by Employment Type in the United Kingdom')
plt.xlabel('Employment Type')
plt.ylabel('Salary (USD)')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend(['Mean', '25th Percentile', 'Median', '75th Percentile'])
plt.show()

# %%
uk_df
# Out:
#       work_year       job_title               job_category salary_currency  \
# 13         2023  Data Scientist  Data Science and Research             GBP
# 14         2023  Data Scientist  Data Science and Research             GBP
# 531        2023  Data Scientist  Data Science and Research             GBP
# 532        2023  Data Scientist  Data Science and Research             GBP
# 559        2023  Data Scientist  Data Science and Research             GBP
# ...         ...             ...                        ...             ...
# 9046       2022  Data Scientist  Data Science and Research             GBP
# 9047       2022  Data Scientist  Data Science and Research             GBP
# 9208       2020  Data Scientist  Data Science and Research             GBP
# 9289       2021  Data Scientist  Data Science and Research             GBP
# 9290       2021  Data Scientist  Data Science and Research             GBP
#
#       salary  salary_in_usd employee_residence experience_level  \
# 13     35000          43064     United Kingdom        Mid-level
# 14     30000          36912     United Kingdom        Mid-level
# 531   140000         172256     United Kingdom           Senior
# 532   100000         123040     United Kingdom           Senior
# 559   100000         123040     United Kingdom        Mid-level
# ...      ...            ...                ...              ...
# 9046  140000         172386     United Kingdom        Mid-level
# 9047   70000          86193     United Kingdom        Mid-level
# 9208   60000          76958     United Kingdom        Mid-level
# 9289   40900          56256     United Kingdom        Mid-level
# 9290   85000         116914     United Kingdom        Mid-level
#
#      employment_type work_setting company_location company_size
# 13         Full-time    In-person   United Kingdom            M
# 14         Full-time    In-person   United Kingdom            M
# 531        Full-time       Remote   United Kingdom            M
# 532        Full-time       Remote   United Kingdom            M
# 559        Full-time    In-person   United Kingdom            M
# ...              ...          ...              ...          ...
# 9046       Full-time    In-person   United Kingdom            M
# 9047       Full-time    In-person   United Kingdom            M
# 9208       Full-time       Remote   United Kingdom            S
# 9289       Full-time       Hybrid   United Kingdom            L
# 9290       Full-time       Hybrid   United Kingdom            L
#
# [76 rows x 12 columns]

# %%
salary_by_employment_type
# Out:
#                  count           mean           std      min       25%  \
# employment_type
# Full-time         76.0  108949.855263  51628.166011  33246.0  72298.75
#
#                      50%       75%       max
# employment_type
# Full-time        99253.0  135508.0  277300.0

# %% [markdown]
# Most Data Scientist  in the UK are full time working on and average salary of 108,949 USD
